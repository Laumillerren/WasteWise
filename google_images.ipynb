# %% [markdown]
# ## Functions to request google images of waste
#
# Limit of 100 images per day on free google API.
#
# API and Programmable search engines were created

# %%
import requests
import os
from PIL import Image
from io import BytesIO
from dotenv import load_dotenv
from datetime import datetime

load_dotenv()
API_KEY = os.getenv("GOOGLE_API_KEY")
CSE_ID = os.getenv("GOOGLE_CSE_ID")

NUM_IMAGES = 20
IMAGE_SIZE = (224, 224)
SAVE_DIR = "./waste_dataset"

categories = {
    "compostable": ["tea bags", "egg shell", "orange peel", "apple core", "carrot tops"]
}

def fetch_images(search_query, category, num_images=NUM_IMAGES):
    url = "https://www.googleapis.com/customsearch/v1"
    images_fetched = 0
    start_index = 1

    while images_fetched < num_images:
        batch_size = min(num_images - images_fetched, 10)
        params = {
            "q": search_query,
            "searchType": "image",
            "key": API_KEY,
            "cx": CSE_ID,
            "num": batch_size,
            "start": start_index
        }

        response = requests.get(url, params=params)
        if response.status_code != 200:
            print(f"Error fetching images: {response.json().get('error', {}).get('message', 'Unknown error')}")
            return

        results = response.json().get("items", [])
        if not results:
            print(f"No more results for {search_query}.")
            break

        if not os.path.exists(f"{SAVE_DIR}/{category}"):
            os.makedirs(f"{SAVE_DIR}/{category}")

        for idx, item in enumerate(results):
            try:
                img_url = item["link"]
                img_data = requests.get(img_url).content
                img = Image.open(BytesIO(img_data)).convert("RGB")
                img = img.resize(IMAGE_SIZE)

                timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                img.save(f"{SAVE_DIR}/{category}/{search_query}_{timestamp}_{images_fetched + idx + 1}.jpg")
                print(f"Saved: {search_query}_{timestamp}_{images_fetched + idx + 1}.jpg")
            except Exception as e:
                print(f"Error with {search_query} image: {e}")

        images_fetched += len(results)
        start_index += len(results)

for category, queries in categories.items():
    for query in queries:
        fetch_images(query, category)

print("Image collection complete")
# Out:
# Saved: tea bags_20250203_083141_1.jpg
# Saved: tea bags_20250203_083142_2.jpg
# Saved: tea bags_20250203_083142_3.jpg
# Saved: tea bags_20250203_083144_4.jpg
# Saved: tea bags_20250203_083144_5.jpg
# Saved: tea bags_20250203_083144_6.jpg
# Saved: tea bags_20250203_083145_7.jpg
# Saved: tea bags_20250203_083145_8.jpg
# Saved: tea bags_20250203_083146_9.jpg
# Saved: tea bags_20250203_083147_10.jpg
# Saved: tea bags_20250203_083148_11.jpg
# Saved: tea bags_20250203_083148_12.jpg
# Saved: tea bags_20250203_083148_13.jpg
# Saved: tea bags_20250203_083148_14.jpg
# Saved: tea bags_20250203_083149_15.jpg
# Saved: tea bags_20250203_083149_16.jpg
# Saved: tea bags_20250203_083149_17.jpg
# Saved: tea bags_20250203_083149_18.jpg
# Saved: tea bags_20250203_083150_19.jpg
# Saved: tea bags_20250203_083150_20.jpg
# Error with egg shell image: cannot identify image file <_io.BytesIO object at 0x10768a3e0>
# Saved: egg shell_20250203_083151_2.jpg
# Error with egg shell image: cannot identify image file <_io.BytesIO object at 0x10768a3e0>
# Saved: egg shell_20250203_083152_4.jpg
# Error with egg shell image: cannot identify image file <_io.BytesIO object at 0x10768a3e0>
# Saved: egg shell_20250203_083153_6.jpg
# Saved: egg shell_20250203_083153_7.jpg
# Saved: egg shell_20250203_083153_8.jpg
# Saved: egg shell_20250203_083153_9.jpg
# Saved: egg shell_20250203_083154_10.jpg
# Saved: egg shell_20250203_083154_11.jpg
# Saved: egg shell_20250203_083155_12.jpg
# Error with egg shell image: cannot identify image file <_io.BytesIO object at 0x10763b880>
# Saved: egg shell_20250203_083156_14.jpg
# Saved: egg shell_20250203_083156_15.jpg
# Saved: egg shell_20250203_083156_16.jpg
# Saved: egg shell_20250203_083208_17.jpg
# Saved: egg shell_20250203_083208_18.jpg
# Saved: egg shell_20250203_083208_19.jpg
# Saved: egg shell_20250203_083208_20.jpg
# Saved: orange peel_20250203_083210_1.jpg
# Saved: orange peel_20250203_083210_2.jpg
# Saved: orange peel_20250203_083211_3.jpg
# Saved: orange peel_20250203_083211_4.jpg
# Saved: orange peel_20250203_083211_5.jpg
# Saved: orange peel_20250203_083214_6.jpg
# Saved: orange peel_20250203_083216_7.jpg
# Saved: orange peel_20250203_083216_8.jpg
# Saved: orange peel_20250203_083217_9.jpg
# Saved: orange peel_20250203_083217_10.jpg
# Saved: orange peel_20250203_083217_11.jpg
# Saved: orange peel_20250203_083218_12.jpg
# Saved: orange peel_20250203_083218_13.jpg
# Error with orange peel image: HTTPSConnectionPool(host='www.sterlingsmilesazle.com', port=443): Max retries exceeded with url: /wp-content/uploads/2021/07/Orange-Peel.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x106b18a10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Saved: orange peel_20250203_083227_15.jpg
# Saved: orange peel_20250203_083227_16.jpg
# Saved: orange peel_20250203_083227_17.jpg
# Error with orange peel image: HTTPSConnectionPool(host='www.sterlingsmilesazle.com', port=443): Max retries exceeded with url: /wp-content/uploads/2021/07/Orange-Peel-1200x900.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x106b1a150>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Saved: orange peel_20250203_083228_19.jpg
# Saved: orange peel_20250203_083228_20.jpg
# Saved: apple core_20250203_083228_1.jpg
# Saved: apple core_20250203_083229_2.jpg
# Saved: apple core_20250203_083229_3.jpg
# Saved: apple core_20250203_083229_4.jpg
# Saved: apple core_20250203_083230_5.jpg
# Error with apple core image: cannot identify image file <_io.BytesIO object at 0x106f9b1a0>
# Error with apple core image: cannot identify image file <_io.BytesIO object at 0x1079306d0>
# Saved: apple core_20250203_083231_8.jpg
# Saved: apple core_20250203_083231_9.jpg
# Saved: apple core_20250203_083231_10.jpg
# Saved: apple core_20250203_083232_11.jpg
# Saved: apple core_20250203_083232_12.jpg
# Saved: apple core_20250203_083233_13.jpg
# Saved: apple core_20250203_083233_14.jpg
# Saved: apple core_20250203_083233_15.jpg
# Saved: apple core_20250203_083233_16.jpg
# Error with apple core image: cannot identify image file <_io.BytesIO object at 0x106f98770>
# Saved: apple core_20250203_083234_18.jpg
# Error with apple core image: cannot identify image file <_io.BytesIO object at 0x106493ab0>
# Saved: apple core_20250203_083234_20.jpg
# Saved: carrot tops_20250203_083235_1.jpg
# Saved: carrot tops_20250203_083235_2.jpg
# Saved: carrot tops_20250203_083235_3.jpg
# Saved: carrot tops_20250203_083235_4.jpg
# Saved: carrot tops_20250203_083236_5.jpg
# Saved: carrot tops_20250203_083236_6.jpg
# Saved: carrot tops_20250203_083239_7.jpg
# Saved: carrot tops_20250203_083240_8.jpg
# Saved: carrot tops_20250203_083240_9.jpg
# Saved: carrot tops_20250203_083240_10.jpg
# Saved: carrot tops_20250203_083241_11.jpg
# Saved: carrot tops_20250203_083242_12.jpg
# Saved: carrot tops_20250203_083242_13.jpg
# Saved: carrot tops_20250203_083242_14.jpg
# Saved: carrot tops_20250203_083242_15.jpg
# Saved: carrot tops_20250203_083243_16.jpg
# Saved: carrot tops_20250203_083243_17.jpg
# Saved: carrot tops_20250203_083243_18.jpg
# Saved: carrot tops_20250203_083243_19.jpg
# Saved: carrot tops_20250203_083244_20.jpg
# Image collection complete

# %% [markdown]
# **Compostable:**
#
# Orange peel
# Apple core
# Banana peel
# Coffee grounds
# Tea bag
# Eggshell
# Paper towel
# Grass clippings
# Leaves
# Bread crust
#
#
# **Non-Recyclable:**
#
# Styrofoam plate
# Plastic wrap
# Pizza box with grease
# Snack wrapper
# Juice box
# Toothpaste tube
# Plastic bag
# Broken glass
# Disposable mask
# Ceramic dish
