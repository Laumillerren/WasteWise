# %% [markdown]
# ## Functions to request google images of waste
#
# Limit of 100 images per day on free google API.
#
# API and Programmable search engines were created

# %%
import requests
import os
from PIL import Image
from io import BytesIO
from dotenv import load_dotenv
from datetime import datetime

load_dotenv()
API_KEY = os.getenv("GOOGLE_API_KEY")
CSE_ID = os.getenv("GOOGLE_CSE_ID")

NUM_IMAGES = 10
IMAGE_SIZE = (224, 224) #size
SAVE_DIR = "./waste_dataset"

#these can be changed to get other images for datasets
categories = {
    "non-recyclable": ["styrofoam cup", "plastic wrap", "cigarette butt"],
    "compostable": ["banana peel", "apple core", "coffee grounds"]
}

def fetch_images(search_query, category, num_images=NUM_IMAGES):
    url = "https://www.googleapis.com/customsearch/v1"
    params = {
        "q": search_query,
        "searchType": "image",
        "key": API_KEY,
        "cx": CSE_ID,
        "num": num_images
    }
    response = requests.get(url, params=params)
    results = response.json().get("items", [])
    
    if not os.path.exists(f"{SAVE_DIR}/{category}"):
        os.makedirs(f"{SAVE_DIR}/{category}")
    
    for idx, item in enumerate(results):
        try:
            img_url = item["link"]
            img_data = requests.get(img_url).content
            img = Image.open(BytesIO(img_data))
            img = img.resize(IMAGE_SIZE)
            
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S") #save images with timestamps so they are unique
            img.save(f"{SAVE_DIR}/{category}/{search_query}_{timestamp}_{idx+1}.jpg")
            print(f"Saved: {search_query}_{timestamp}_{idx+1}.jpg")
        except Exception as e:
            print(f"Error with {search_query}: {e}") #some images error

for category, queries in categories.items():
    for query in queries:
        fetch_images(query, category)

print("Image collection complete")
# Out:
# Saved: styrofoam cup_20250117_091954_1.jpg
# Saved: styrofoam cup_20250117_091954_2.jpg
# Saved: styrofoam cup_20250117_091954_3.jpg
# Error with styrofoam cup: cannot write mode RGBA as JPEG
# Saved: styrofoam cup_20250117_091955_5.jpg
# Error with styrofoam cup: cannot write mode RGBA as JPEG
# Saved: styrofoam cup_20250117_091955_7.jpg
# Saved: styrofoam cup_20250117_091955_8.jpg
# Saved: styrofoam cup_20250117_091956_9.jpg
# Error with styrofoam cup: cannot write mode RGBA as JPEG
# Saved: plastic wrap_20250117_091957_1.jpg
# Saved: plastic wrap_20250117_091957_2.jpg
# Saved: plastic wrap_20250117_091957_3.jpg
# Saved: plastic wrap_20250117_091957_4.jpg
# Saved: plastic wrap_20250117_091957_5.jpg
# Saved: plastic wrap_20250117_091958_6.jpg
# Saved: plastic wrap_20250117_091958_7.jpg
# Saved: plastic wrap_20250117_091958_8.jpg
# Error with plastic wrap: cannot identify image file <_io.BytesIO object at 0x1055aa480>
# Saved: plastic wrap_20250117_091958_10.jpg
# Saved: cigarette butt_20250117_092000_1.jpg
# Saved: cigarette butt_20250117_092000_2.jpg
# Error with cigarette butt: cannot identify image file <_io.BytesIO object at 0x104996a20>
# Error with cigarette butt: cannot write mode P as JPEG
# Saved: cigarette butt_20250117_092001_5.jpg
# Saved: cigarette butt_20250117_092002_6.jpg
# Saved: cigarette butt_20250117_092003_7.jpg
# Saved: cigarette butt_20250117_092003_8.jpg
# Saved: cigarette butt_20250117_092003_9.jpg
# Saved: cigarette butt_20250117_092003_10.jpg
# Error with banana peel: cannot identify image file <_io.BytesIO object at 0x105b9c810>
# Error with banana peel: cannot write mode RGBA as JPEG
# Saved: banana peel_20250117_092005_3.jpg
# Error with banana peel: cannot write mode RGBA as JPEG
# Saved: banana peel_20250117_092005_5.jpg
# Saved: banana peel_20250117_092005_6.jpg
# Saved: banana peel_20250117_092009_7.jpg
# Saved: banana peel_20250117_092009_8.jpg
# Saved: banana peel_20250117_092010_9.jpg
# Saved: banana peel_20250117_092010_10.jpg
# Saved: apple core_20250117_092011_1.jpg
# Saved: apple core_20250117_092011_2.jpg
# Saved: apple core_20250117_092012_3.jpg
# Saved: apple core_20250117_092012_4.jpg
# Error with apple core: cannot write mode RGBA as JPEG
# Saved: apple core_20250117_092012_6.jpg
# Error with apple core: cannot identify image file <_io.BytesIO object at 0x105b77380>
# Saved: apple core_20250117_092013_8.jpg
# Saved: apple core_20250117_092013_9.jpg
# Saved: apple core_20250117_092014_10.jpg
# Saved: coffee grounds_20250117_092014_1.jpg
# Saved: coffee grounds_20250117_092015_2.jpg
# Saved: coffee grounds_20250117_092015_3.jpg
# Saved: coffee grounds_20250117_092015_4.jpg
# Saved: coffee grounds_20250117_092015_5.jpg
# Error with coffee grounds: cannot write mode P as JPEG
# Saved: coffee grounds_20250117_092016_7.jpg
# Saved: coffee grounds_20250117_092016_8.jpg
# Saved: coffee grounds_20250117_092017_9.jpg
# Error with coffee grounds: cannot identify image file <_io.BytesIO object at 0x104ee3790>
# Image collection complete

# %% [markdown]
# **Compostable:**
#
# Orange peel
# Apple core
# Banana peel
# Coffee grounds
# Tea bag
# Eggshell
# Paper towel
# Grass clippings
# Leaves
# Bread crust
#
#
# **Non-Recyclable:**
#
# Styrofoam plate
# Plastic wrap
# Pizza box with grease
# Snack wrapper
# Juice box
# Toothpaste tube
# Plastic bag
# Broken glass
# Disposable mask
# Ceramic dish
