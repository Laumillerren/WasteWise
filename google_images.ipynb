# %% [markdown]
# ## Functions to request google images of waste
#
# Limit of 100 images per day on free google API.
#
# API and Programmable search engines were created

# %%
import requests
import os
from PIL import Image
from io import BytesIO
from dotenv import load_dotenv
from datetime import datetime

load_dotenv()
API_KEY = os.getenv("GOOGLE_API_KEY")
CSE_ID = os.getenv("GOOGLE_CSE_ID")

NUM_IMAGES = 10
IMAGE_SIZE = (224, 224) #size
SAVE_DIR = "./waste_dataset"

#these can be changed to get other images for datasets
categories = {
    "recyclable": ["plastic bottle", "glass jar", "newspaper"],
    "non-recyclable": ["styrofoam cup", "plastic wrap", "cigarette butt"],
    "compostable": ["banana peel", "apple core", "coffee grounds"]
}

def fetch_images(search_query, category, num_images=NUM_IMAGES):
    url = "https://www.googleapis.com/customsearch/v1"
    params = {
        "q": search_query,
        "searchType": "image",
        "key": API_KEY,
        "cx": CSE_ID,
        "num": num_images
    }
    response = requests.get(url, params=params)
    results = response.json().get("items", [])
    
    if not os.path.exists(f"{SAVE_DIR}/{category}"):
        os.makedirs(f"{SAVE_DIR}/{category}")
    
    for idx, item in enumerate(results):
        try:
            img_url = item["link"]
            img_data = requests.get(img_url).content
            img = Image.open(BytesIO(img_data))
            img = img.resize(IMAGE_SIZE)
            
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S") #save images with timestamps so they are unique
            img.save(f"{SAVE_DIR}/{category}/{search_query}_{timestamp}_{idx+1}.jpg")
            print(f"Saved: {search_query}_{timestamp}_{idx+1}.jpg")
        except Exception as e:
            print(f"Error with {search_query}: {e}") #some images error

for category, queries in categories.items():
    for query in queries:
        fetch_images(query, category)

print("Image collection complete")
# Out:
# Error with plastic bottle: cannot identify image file <_io.BytesIO object at 0x10c55a890>
# Saved: plastic bottle_20250113_071701_2.jpg
# Saved: plastic bottle_20250113_071702_3.jpg
# Saved: plastic bottle_20250113_071702_4.jpg
# Saved: plastic bottle_20250113_071702_5.jpg
# Saved: plastic bottle_20250113_071703_6.jpg
# Saved: plastic bottle_20250113_071703_7.jpg
# Saved: plastic bottle_20250113_071704_8.jpg
# Saved: plastic bottle_20250113_071705_9.jpg
# Saved: plastic bottle_20250113_071705_10.jpg
# Saved: glass jar_20250113_071706_1.jpg
# Saved: glass jar_20250113_071707_2.jpg
# Saved: glass jar_20250113_071707_3.jpg
# Saved: glass jar_20250113_071707_4.jpg
# Saved: glass jar_20250113_071707_5.jpg
# Saved: glass jar_20250113_071708_6.jpg
# Saved: glass jar_20250113_071708_7.jpg
# Saved: glass jar_20250113_071708_8.jpg
# Saved: glass jar_20250113_071709_9.jpg
# Saved: glass jar_20250113_071709_10.jpg
# Saved: newspaper_20250113_071710_1.jpg
# Error with newspaper: cannot identify image file <_io.BytesIO object at 0x10c0e3830>
# Saved: newspaper_20250113_071711_3.jpg
# Error with newspaper: cannot write mode RGBA as JPEG
# Saved: newspaper_20250113_071714_5.jpg
# Error with newspaper: cannot write mode RGBA as JPEG
# Saved: newspaper_20250113_071714_7.jpg
# Saved: newspaper_20250113_071715_8.jpg
# Saved: newspaper_20250113_071716_9.jpg
# Saved: newspaper_20250113_071717_10.jpg
# Saved: styrofoam cup_20250113_071718_1.jpg
# Saved: styrofoam cup_20250113_071718_2.jpg
# Saved: styrofoam cup_20250113_071718_3.jpg
# Error with styrofoam cup: cannot write mode RGBA as JPEG
# Saved: styrofoam cup_20250113_071719_5.jpg
# Error with styrofoam cup: cannot write mode RGBA as JPEG
# Saved: styrofoam cup_20250113_071720_7.jpg
# Saved: styrofoam cup_20250113_071720_8.jpg
# Error with styrofoam cup: cannot write mode RGBA as JPEG
# Saved: styrofoam cup_20250113_071721_10.jpg
# Saved: plastic wrap_20250113_071722_1.jpg
# Saved: plastic wrap_20250113_071722_2.jpg
# Saved: plastic wrap_20250113_071722_3.jpg
# Saved: plastic wrap_20250113_071723_4.jpg
# Saved: plastic wrap_20250113_071723_5.jpg
# Saved: plastic wrap_20250113_071723_6.jpg
# Error with plastic wrap: cannot identify image file <_io.BytesIO object at 0x10c558e00>
# Saved: plastic wrap_20250113_071724_8.jpg
# Saved: plastic wrap_20250113_071724_9.jpg
# Saved: plastic wrap_20250113_071724_10.jpg
# Saved: cigarette butt_20250113_071726_1.jpg
# Saved: cigarette butt_20250113_071727_2.jpg
# Error with cigarette butt: cannot identify image file <_io.BytesIO object at 0x10c5798a0>
# Error with cigarette butt: cannot write mode P as JPEG
# Saved: cigarette butt_20250113_071730_5.jpg
# Saved: cigarette butt_20250113_071731_6.jpg
# Saved: cigarette butt_20250113_071732_7.jpg
# Saved: cigarette butt_20250113_071732_8.jpg
# Saved: cigarette butt_20250113_071733_9.jpg
# Saved: cigarette butt_20250113_071733_10.jpg
# Error with banana peel: cannot identify image file <_io.BytesIO object at 0x10cb28770>
# Error with banana peel: cannot write mode RGBA as JPEG
# Saved: banana peel_20250113_071735_3.jpg
# Saved: banana peel_20250113_071735_4.jpg
# Error with banana peel: cannot write mode RGBA as JPEG
# Saved: banana peel_20250113_071736_6.jpg
# Saved: banana peel_20250113_071736_7.jpg
# Saved: banana peel_20250113_071738_8.jpg
# Saved: banana peel_20250113_071738_9.jpg
# Saved: banana peel_20250113_071739_10.jpg
# Saved: apple core_20250113_071740_1.jpg
# Saved: apple core_20250113_071740_2.jpg
# Saved: apple core_20250113_071741_3.jpg
# Saved: apple core_20250113_071741_4.jpg
# Error with apple core: cannot write mode RGBA as JPEG
# Saved: apple core_20250113_071742_6.jpg
# Error with apple core: cannot identify image file <_io.BytesIO object at 0x10c578c20>
# Saved: apple core_20250113_071742_8.jpg
# Saved: apple core_20250113_071743_9.jpg
# Error with apple core: cannot write mode RGBA as JPEG
# Saved: coffee grounds_20250113_071744_1.jpg
# Saved: coffee grounds_20250113_071744_2.jpg
# Saved: coffee grounds_20250113_071745_3.jpg
# Saved: coffee grounds_20250113_071745_4.jpg
# Saved: coffee grounds_20250113_071746_5.jpg
# Saved: coffee grounds_20250113_071746_6.jpg
# Error with coffee grounds: cannot write mode P as JPEG
# Saved: coffee grounds_20250113_071747_8.jpg
# Saved: coffee grounds_20250113_071747_9.jpg
# Saved: coffee grounds_20250113_071748_10.jpg
# Image collection complete
