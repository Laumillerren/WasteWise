# %% [markdown]
# ## Functions to request google images of waste
#
# Limit of 100 images per day on free google API.
#
# API and Programmable search engines were created

# %%
import requests
import os
from PIL import Image
from io import BytesIO
from dotenv import load_dotenv
from datetime import datetime

load_dotenv()
API_KEY = os.getenv("GOOGLE_API_KEY")
CSE_ID = os.getenv("GOOGLE_CSE_ID")

NUM_IMAGES = 10
IMAGE_SIZE = (224, 224) #size
SAVE_DIR = "./waste_dataset"

#these can be changed to get other images for datasets
categories = {
    "recyclable": ["plastic bottle", "glass jar", "newspaper"],
    "non-recyclable": ["styrofoam cup", "plastic wrap", "cigarette butt"],
    "compostable": ["banana peel", "apple core", "coffee grounds"]
}

def fetch_images(search_query, category, num_images=NUM_IMAGES):
    url = "https://www.googleapis.com/customsearch/v1"
    params = {
        "q": search_query,
        "searchType": "image",
        "key": API_KEY,
        "cx": CSE_ID,
        "num": num_images
    }
    response = requests.get(url, params=params)
    results = response.json().get("items", [])
    
    if not os.path.exists(f"{SAVE_DIR}/{category}"):
        os.makedirs(f"{SAVE_DIR}/{category}")
    
    for idx, item in enumerate(results):
        try:
            img_url = item["link"]
            img_data = requests.get(img_url).content
            img = Image.open(BytesIO(img_data))
            img = img.resize(IMAGE_SIZE)
            
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S") #save images with timestamps so they are unique
            img.save(f"{SAVE_DIR}/{category}/{search_query}_{timestamp}_{idx+1}.jpg")
            print(f"Saved: {search_query}_{timestamp}_{idx+1}.jpg")
        except Exception as e:
            print(f"Error with {search_query}: {e}") #some images error

for category, queries in categories.items():
    for query in queries:
        fetch_images(query, category)

print("Image collection complete")
# Out:
# Error with plastic bottle: cannot identify image file <_io.BytesIO object at 0x10cb07f10>
# Saved: plastic bottle_20250115_064616_2.jpg
# Saved: plastic bottle_20250115_064617_3.jpg
# Saved: plastic bottle_20250115_064617_4.jpg
# Saved: plastic bottle_20250115_064617_5.jpg
# Saved: plastic bottle_20250115_064618_6.jpg
# Saved: plastic bottle_20250115_064618_7.jpg
# Saved: plastic bottle_20250115_064619_8.jpg
# Saved: plastic bottle_20250115_064619_9.jpg
# Saved: plastic bottle_20250115_064620_10.jpg
# Saved: glass jar_20250115_064621_1.jpg
# Saved: glass jar_20250115_064621_2.jpg
# Saved: glass jar_20250115_064622_3.jpg
# Saved: glass jar_20250115_064622_4.jpg
# Saved: glass jar_20250115_064623_5.jpg
# Saved: glass jar_20250115_064623_6.jpg
# Saved: glass jar_20250115_064623_7.jpg
# Saved: glass jar_20250115_064623_8.jpg
# Saved: glass jar_20250115_064624_9.jpg
# Saved: glass jar_20250115_064624_10.jpg
# Saved: newspaper_20250115_064626_1.jpg
# Saved: newspaper_20250115_064626_2.jpg
# Error with newspaper: cannot identify image file <_io.BytesIO object at 0x10c578c70>
# Saved: newspaper_20250115_064628_4.jpg
# Error with newspaper: cannot write mode RGBA as JPEG
# Saved: newspaper_20250115_064635_6.jpg
# Error with newspaper: cannot write mode RGBA as JPEG
# Saved: newspaper_20250115_064637_8.jpg
# Saved: newspaper_20250115_064637_9.jpg
# Error with newspaper: cannot write mode RGBA as JPEG
# Saved: styrofoam cup_20250115_064639_1.jpg
# Saved: styrofoam cup_20250115_064639_2.jpg
# Saved: styrofoam cup_20250115_064640_3.jpg
# Error with styrofoam cup: cannot write mode RGBA as JPEG
# Saved: styrofoam cup_20250115_064641_5.jpg
# Error with styrofoam cup: cannot write mode RGBA as JPEG
# Saved: styrofoam cup_20250115_064641_7.jpg
# Saved: styrofoam cup_20250115_064641_8.jpg
# Error with styrofoam cup: cannot write mode RGBA as JPEG
# Saved: styrofoam cup_20250115_064642_10.jpg
# Saved: plastic wrap_20250115_064643_1.jpg
# Saved: plastic wrap_20250115_064644_2.jpg
# Saved: plastic wrap_20250115_064644_3.jpg
# Saved: plastic wrap_20250115_064644_4.jpg
# Saved: plastic wrap_20250115_064645_5.jpg
# Saved: plastic wrap_20250115_064645_6.jpg
# Saved: plastic wrap_20250115_064646_7.jpg
# Saved: plastic wrap_20250115_064646_8.jpg
# Saved: plastic wrap_20250115_064646_9.jpg
# Saved: plastic wrap_20250115_064646_10.jpg
# Saved: cigarette butt_20250115_064649_1.jpg
# Saved: cigarette butt_20250115_064650_2.jpg
# Error with cigarette butt: cannot identify image file <_io.BytesIO object at 0x10c100590>
# Error with cigarette butt: cannot write mode P as JPEG
# Saved: cigarette butt_20250115_064652_5.jpg
# Saved: cigarette butt_20250115_064654_6.jpg
# Saved: cigarette butt_20250115_064654_7.jpg
# Saved: cigarette butt_20250115_064655_8.jpg
# Saved: cigarette butt_20250115_064655_9.jpg
# Error with cigarette butt: cannot identify image file <_io.BytesIO object at 0x10c0e3830>
# Saved: banana peel_20250115_064656_1.jpg
# Saved: banana peel_20250115_064657_2.jpg
# Error with banana peel: cannot write mode RGBA as JPEG
# Saved: banana peel_20250115_064658_4.jpg
# Error with banana peel: cannot write mode RGBA as JPEG
# Saved: banana peel_20250115_064659_6.jpg
# Saved: banana peel_20250115_064700_7.jpg
# Saved: banana peel_20250115_064701_8.jpg
# Saved: banana peel_20250115_064701_9.jpg
# Saved: banana peel_20250115_064701_10.jpg
# Saved: apple core_20250115_064702_1.jpg
# Saved: apple core_20250115_064703_2.jpg
# Saved: apple core_20250115_064703_3.jpg
# Saved: apple core_20250115_064704_4.jpg
# Error with apple core: cannot write mode RGBA as JPEG
# Saved: apple core_20250115_064706_6.jpg
# Error with apple core: cannot identify image file <_io.BytesIO object at 0x10c0e26b0>
# Saved: apple core_20250115_064707_8.jpg
# Saved: apple core_20250115_064707_9.jpg
# Error with apple core: cannot identify image file <_io.BytesIO object at 0x10c100180>
# Saved: coffee grounds_20250115_064709_1.jpg
# Saved: coffee grounds_20250115_064710_2.jpg
# Saved: coffee grounds_20250115_064710_3.jpg
# Saved: coffee grounds_20250115_064711_4.jpg
# Saved: coffee grounds_20250115_064711_5.jpg
# Error with coffee grounds: cannot write mode P as JPEG
# Saved: coffee grounds_20250115_064713_7.jpg
# Saved: coffee grounds_20250115_064713_8.jpg
# Saved: coffee grounds_20250115_064714_9.jpg
# Saved: coffee grounds_20250115_064716_10.jpg
# Image collection complete
