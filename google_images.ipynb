# %% [markdown]
# ## Functions to request google images of waste
#
# Limit of 100 images per day on free google API.
#
# API and Programmable search engines were created

# %%
import requests
import os
from PIL import Image
from io import BytesIO
from dotenv import load_dotenv
from datetime import datetime

load_dotenv()
API_KEY = os.getenv("GOOGLE_API_KEY")
CSE_ID = os.getenv("GOOGLE_CSE_ID")

NUM_IMAGES = 10
IMAGE_SIZE = (224, 224)
SAVE_DIR = "./waste_dataset"

categories = {
    "recyclable": ["plastic bottle", "glass jar", "newspaper"],
    "non-recyclable": ["styrofoam cup", "plastic wrap", "cigarette butt"],
    "compostable": ["banana peel", "apple core", "coffee grounds"]
}

def fetch_images(search_query, category, num_images=NUM_IMAGES):
    url = "https://www.googleapis.com/customsearch/v1"
    params = {
        "q": search_query,
        "searchType": "image",
        "key": API_KEY,
        "cx": CSE_ID,
        "num": num_images
    }
    response = requests.get(url, params=params)
    results = response.json().get("items", [])
    
    if not os.path.exists(f"{SAVE_DIR}/{category}"):
        os.makedirs(f"{SAVE_DIR}/{category}")
    
    for idx, item in enumerate(results):
        try:
            img_url = item["link"]
            img_data = requests.get(img_url).content
            img = Image.open(BytesIO(img_data))
            img = img.resize(IMAGE_SIZE)
            
            # Unique timestamp-based filename
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            img.save(f"{SAVE_DIR}/{category}/{search_query}_{timestamp}_{idx+1}.jpg")
            print(f"Saved: {search_query}_{timestamp}_{idx+1}.jpg")
        except Exception as e:
            print(f"Error with {search_query}: {e}")

for category, queries in categories.items():
    for query in queries:
        fetch_images(query, category)

print("Image collection complete")
# Out:
# Error with plastic bottle: cannot identify image file <_io.BytesIO object at 0x10cb28950>
# Saved: plastic bottle_20250112_153900_2.jpg
# Saved: plastic bottle_20250112_153900_3.jpg
# Saved: plastic bottle_20250112_153901_4.jpg
# Saved: plastic bottle_20250112_153901_5.jpg
# Saved: plastic bottle_20250112_153902_6.jpg
# Saved: plastic bottle_20250112_153902_7.jpg
# Saved: plastic bottle_20250112_153903_8.jpg
# Saved: plastic bottle_20250112_153904_9.jpg
# Saved: plastic bottle_20250112_153904_10.jpg
# Saved: glass jar_20250112_153905_1.jpg
# Saved: glass jar_20250112_153906_2.jpg
# Saved: glass jar_20250112_153906_3.jpg
# Saved: glass jar_20250112_153906_4.jpg
# Saved: glass jar_20250112_153906_5.jpg
# Saved: glass jar_20250112_153906_6.jpg
# Saved: glass jar_20250112_153907_7.jpg
# Saved: glass jar_20250112_153907_8.jpg
# Saved: glass jar_20250112_153908_9.jpg
# Saved: glass jar_20250112_153908_10.jpg
# Saved: newspaper_20250112_153908_1.jpg
# Error with newspaper: cannot identify image file <_io.BytesIO object at 0x10cb062f0>
# Saved: newspaper_20250112_153909_3.jpg
# Error with newspaper: cannot write mode RGBA as JPEG
# Saved: newspaper_20250112_153912_5.jpg
# Error with newspaper: cannot write mode RGBA as JPEG
# Saved: newspaper_20250112_153913_7.jpg
# Saved: newspaper_20250112_153914_8.jpg
# Error with newspaper: cannot identify image file <_io.BytesIO object at 0x10c1004f0>
# Saved: newspaper_20250112_153914_10.jpg
